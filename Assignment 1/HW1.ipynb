# %%
key = [2,ord('F'),4,5,ord('d'),ord('x'),9,7,ord('A'),ord('B'),ord('e'),2,2,3,2,3] ########################KEY
#plaintext = [ord('A'),ord('E'),ord('S'),ord('i'),ord('m'),ord('p'),ord('l'),ord('e'),ord('m'),ord('e'),ord('n'),ord('t'),ord('b'),ord('y'),ord('m'),ord('e')] #######################16bit plaintext
key1 = "2F45dx97ABe22323"
plaintext = "AESimplementebyme"
plt = plaintext.encode(encoding='utf-8')
key2 = key1.encode(encoding='utf-8')
#print(plt)
output = [0] * 176
s = [0] * 16

# Rijndael S-box
sbox = []

# Rijndael Rcon
Rcon = []



def galois_multiplication( a, b):
        p = 0
        for counter in range(8):
            if b & 1: p ^= a
            hi_bit_set = a & 0x80
            a <<= 1
            # keep a 8 bit
            a &= 0xFF
            if hi_bit_set:
                a ^= 0x1b
            b >>= 1
        return p

    # galois multiplication of the 4x4 matrix
def mixColumns( state, isInv):
        # iterate over the 4 columns
        for i in range(4):
            # extract each column in the state matrix
            # 1st col is [97, 98, 99 ,100]
            column = state[i:i+16:4]
            # apply the mixColumn on one column
            column = mixColumn(column, isInv)
            # put the values back into the state
            state[i:i+16:4] = column
        return state

    # galois multiplication of 1 column of the 4x4 matrix
    # isInv = False when encoding; True when decoding
def mixColumn( column, isInv):
        if isInv:
            mult = [14, 9, 13, 11]
        else:
            mult = [2, 1, 1, 3]
        cpy = list(column)
        g = galois_multiplication

        column[0] = g(cpy[0], mult[0]) ^ g(cpy[3], mult[1]) ^ \
                    g(cpy[2], mult[2]) ^ g(cpy[1], mult[3])
        column[1] = g(cpy[1], mult[0]) ^ g(cpy[0], mult[1]) ^ \
                    g(cpy[3], mult[2]) ^ g(cpy[2], mult[3])
        column[2] = g(cpy[2], mult[0]) ^ g(cpy[1], mult[1]) ^ \
                    g(cpy[0], mult[2]) ^ g(cpy[3], mult[3])
        column[3] = g(cpy[3], mult[0]) ^ g(cpy[2], mult[1]) ^ \
                    g(cpy[1], mult[2]) ^ g(cpy[0], mult[3])
        return column


def matrix(text):
    #Converts plaintext array into a 4x4 matrix
    s = [list(text[i:i+4]) for i in range(0, len(text), 4)]
    return s

def subBytes(s):
    for i in range(16):
        s[i] = sbox[s[i]] #find the index location in sbox
    return s
    
    
def shiftRows(s):
    s[0][1], s[1][1], s[2][1], s[3][1] = s[1][1], s[2][1], s[3][1], s[0][1]
    s[0][2], s[1][2], s[2][2], s[3][2] = s[2][2], s[3][2], s[0][2], s[1][2]
    s[0][3], s[1][3], s[2][3], s[3][3] = s[3][3], s[0][3], s[1][3], s[2][3]
    return s
 
def addRoundKey(s,roundKey):
    for i in range(16):
        s[i] = s[i] ^ roundKey[i]
    return s
    
    
def rotWord(s):
    tmp = s[0]
    for i in range(3):
        s[i] = s[i+1]
    s[3] = tmp
    return s

def subWord(s):
    for i in range(4):
        s[i] = sbox[i]
    return s


def keyExpansion(inputKey, outputKey):
    temp = [0] * 4 
    rc = 1
    bytesGenerated = 16
    for i in range(16):
        outputKey[i] = inputKey[i]
    
    
    while bytesGenerated<176:
        #print(temp)
        for i in range(4):
            temp[i] = outputKey[i + bytesGenerated - 4]
    
        if(bytesGenerated % 16 ==0):
            temp = subWord(rotWord(temp))
            for q in range(4):
                temp[q] = temp[q]^Rcon[rc]
            rc = rc+1   
       
        
        #print(outputKey)
        #print(temp)
        for n in range(4):
            outputKey[bytesGenerated] = outputKey[bytesGenerated -16] ^ temp[n]
            
        bytesGenerated = bytesGenerated + 4
    return outputKey



def encrypt(message, key):
    for i in range(16):
        s[i] = message[i]
    
        z=[[0]*4]*4 
    #print(s)
    numOfRounds = 10;
    expKey = [0] *176
    keyExpansion(key, expKey)
    print(expKey)
    c = 0
    for i in range(0, numOfRounds):
        subBytes(s)
        for n in range(4):
            for q in range(4):
                z[n][q] = s[c]
                c=c+1
        print(z)
        shiftRows(z)
        mixColumns(z, False)
        addRoundKey(z,expKey[i + (16*(i+1))])
    
    subWord(z)
    shuftRows(z)
    addRoundKey(z,expKey + 160)
    

encrypt(plt,key2)


#addRoundKey(s,keyExpansion(key2,output))
#print(subBytes(matrix(plt)))
#going from c to python is hell
#note to self: start earlier next time
# Out:
# [50, 70, 52, 53, 100, 120, 57, 55, 65, 66, 101, 50, 50, 51, 50, 51, 72, 0, 0, 0, 100, 0, 0, 0, 65, 0, 0, 0, 50, 0, 0, 0, 49, 0, 0, 0, 100, 0, 0, 0, 65, 0, 0, 0, 50, 0, 0, 0, 78, 0, 0, 0, 100, 0, 0, 0, 65, 0, 0, 0, 50, 0, 0, 0, 61, 0, 0, 0, 100, 0, 0, 0, 65, 0, 0, 0, 50, 0, 0, 0, 86, 0, 0, 0, 100, 0, 0, 0, 65, 0, 0, 0, 50, 0, 0, 0, 13, 0, 0, 0, 100, 0, 0, 0, 65, 0, 0, 0, 50, 0, 0, 0, 54, 0, 0, 0, 100, 0, 0, 0, 65, 0, 0, 0, 50, 0, 0, 0, 205, 0, 0, 0, 100, 0, 0, 0, 65, 0, 0, 0, 50, 0, 0, 0, 173, 0, 0, 0, 100, 0, 0, 0, 65, 0, 0, 0, 50, 0, 0, 0, 224, 0, 0, 0, 100, 0, 0, 0, 65, 0, 0, 0, 50, 0, 0, 0]
# [[77, 170, 182, 60], [77, 170, 182, 60], [77, 170, 182, 60], [77, 170, 182, 60]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-174-c76839dfb708> in <module>
#     205
#     206
# --> 207 encrypt(plt,key2)
#     208
#     209
#
# ...
